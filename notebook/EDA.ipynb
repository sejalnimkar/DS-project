# %% [markdown]
# Problem Statement: To determine the effect of students' background on their test scores
#
# - Dataset Source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
# - The data consists of 8 column and 1000 rows.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('stud.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# Performing Checks

# %%
#Null values present ?
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#duplicates ?
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#unique values
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
#statistics
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Exploring Categorical data
print("Categories in 'gender' variable:  ",end=" " )
print(df['gender'].unique())

print("Categories in 'race_ethnicity' variable:  ",end=" ")
print(df['race_ethnicity'].unique())

print("Categories in'parental level of education' variable:",end=" " )
print(df['parental_level_of_education'].unique())

print("Categories in 'lunch' variable:     ",end=" " )
print(df['lunch'].unique())

print("Categories in 'test preparation course' variable:     ",end=" " )
print(df['test_preparation_course'].unique())
# Out:
# Categories in 'gender' variable:   ['female' 'male']
# Categories in 'race_ethnicity' variable:   ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in'parental level of education' variable: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' variable:      ['standard' 'free/reduced']
# Categories in 'test preparation course' variable:      ['none' 'completed']

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype!='object']
categorical_features=[feature for feature in df.columns if df[feature].dtype=='object']

print("We have {} numerical features: {}".format(len(numeric_features), numeric_features))

print("We have {} categorical features: {}".format(len(categorical_features), categorical_features))
# Out:
# We have 3 numerical features: ['math_score', 'reading_score', 'writing_score']
# We have 5 categorical features: ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

# %%
#Adding column for total score and average
df['total_score']=df['math_score']+df['reading_score']+df['writing_score']
df['average']=df['total_score']/3

df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
reading_full= (df['reading_score']==100).sum()
math_full= (df['math_score']==100).sum()
writing_full= (df['writing_score']==100).sum()

print("No. of students with full in Maths: ", math_full)
print("No. of students with full in Reading: ", reading_full)
print("No. of students with full in Writing: ", writing_full)
# Out:
# No. of students with full in Maths:  7
# No. of students with full in Reading:  17
# No. of students with full in Writing:  14

# %%
#backbenchers

reading_20= (df['reading_score']<=20).sum()
math_20= (df['math_score']<=20).sum()
writing_20= (df['writing_score']<=20).sum()

print("No. of students with less than 20 in Maths: ", math_20)
print("No. of students with less than 20 in Reading: ", reading_20)
print("No. of students with less than 20 in Writing: ", writing_20)
# Out:
# No. of students with less than 20 in Maths:  4
# No. of students with less than 20 in Reading:  1
# No. of students with less than 20 in Writing:  3

# %% [markdown]
# Visualizations

# %%
fig,axs=plt.subplots(1,2,figsize=(15,7))
# plt.subplot(1,2,1)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g',ax=axs[0])

# plt.subplot(1,2,2)
sns.histplot(data=df, x='average',bins=30,kde=True,hue='gender',ax=axs[1])

plt.show()

# %%
fig,axs=plt.subplots(2,1,figsize=(15,7))
# plt.subplot(1,2,1)
sns.histplot(data=df,x='total_score',bins=30,kde=True,color='g',ax=axs[0])

# plt.subplot(1,2,2)
sns.histplot(data=df, x='total_score',bins=30,kde=True,hue='gender',ax=axs[1])
fig.suptitle("Histogram for Total Score")
# Out:
# Text(0.5, 0.98, 'Histogram for Total Score')

# %% [markdown]
# Insights: Female students perform better than male students

# %%
plt.subplots(1,3,figsize=(25,6))

plt.subplot(1,3,1)
sns.histplot(data=df, x='average',kde=True,hue='lunch')

plt.subplot(1,3,2)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')

plt.subplot(1,3,3)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')

plt.suptitle("Effect of lunch on Score")
plt.show()

# %% [markdown]
# Standard Lunch has a positive effect on score than free/reduced lunch

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='parental_level_of_education')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental_level_of_education')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='parental_level_of_education')
plt.suptitle("Effect of Parental Education on Score")
plt.show()

# %% [markdown]
# Parental Education do not have a strong correlation on students' score

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race_ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race_ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race_ethnicity')
plt.show()

# %% [markdown]
# Group A and Group B have similar performance and that they tend to score somewhat less

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.suptitle("Percentage of students belonging to the given category")
plt.grid()

plt.show()

# %%
plt.subplots(3, 1, figsize=(15, 18))

plt.subplot(3, 1, 1)
sns.boxplot(x='parental_level_of_education', y='math_score', data=df, color='pink')
plt.xticks(rotation=45)

plt.subplot(3, 1, 2)
sns.boxplot(x='parental_level_of_education', y='reading_score', data=df, color='lightgreen')
plt.xticks(rotation=45)

plt.subplot(3, 1, 3)
sns.boxplot(x='parental_level_of_education', y='writing_score', data=df, color='skyblue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots for parents who have obtained Bachelor's Degree or Master's Degree have medians slighlty higher than the rest for all 3 scores

# %%
plt.subplots(1, 3, figsize=(25, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x='gender', y='math_score', data=df, color='pink')
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
sns.boxplot(x='gender', y='reading_score', data=df, color='lightgreen')
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
sns.boxplot(x='gender', y='writing_score', data=df, color='skyblue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# For math, male students score higher than female students whereas for the other 2 subjects, female score higher.

# %%
plt.subplots(1, 3, figsize=(25, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x='lunch', y='math_score', data=df, color='pink')
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
sns.boxplot(x='lunch', y='reading_score', data=df, color='lightgreen')
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
sns.boxplot(x='lunch', y='writing_score', data=df, color='skyblue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplot confirm that Standard lunches improve scores than Free/Reduced lunches since the median for the boxplot for standard lunch is higher

# %%
plt.subplots(1, 3, figsize=(25, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x='test_preparation_course', y='math_score', data=df, color='pink')
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
sns.boxplot(x='test_preparation_course', y='reading_score', data=df, color='lightgreen')
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
sns.boxplot(x='test_preparation_course', y='writing_score', data=df, color='skyblue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Attempting Test preparation courses improves students' scores in all subjects

# %%
plt.subplots(3, 1, figsize=(15, 18))

plt.subplot(3, 1, 1)
sns.boxplot(x='race_ethnicity', y='math_score', data=df, color='pink')
plt.xticks(rotation=45)

plt.subplot(3, 1, 2)
sns.boxplot(x='race_ethnicity', y='reading_score', data=df, color='lightgreen')
plt.xticks(rotation=45)

plt.subplot(3, 1, 3)
sns.boxplot(x='race_ethnicity', y='writing_score', data=df, color='skyblue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above boxplots indicate that :
# - Group A has the least scores in all subjects, followed by Group B
# - Group E has scored the highest among all groups in reading and math but competes with Group D in writing
